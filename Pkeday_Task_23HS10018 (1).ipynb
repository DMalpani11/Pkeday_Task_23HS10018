# %%
import pandas as pd
import numpy as np
import yfinance as yf
import os
import warnings
import time
import matplotlib.pyplot as plt
import concurrent.futures
import pickle

# %%
warnings.filterwarnings('ignore', category=FutureWarning)

# Step 1: Load and Profile Raw Data
file_path = r'C:\Users\DELL\Downloads\raw_nse_insider.csv'

try:
    insider_df = pd.read_csv(file_path, low_memory=False)
    print("Successfully loaded the dataset.")
    print(f"The dataset has {insider_df.shape[0]} rows and {insider_df.shape[1]} columns.")
    print("First 5 rows of the data:")
    print(insider_df.head())
    print("\nDataset Information:")
    insider_df.info()

    df_raw = pd.read_csv(file_path, low_memory=False)
    df_raw.columns = [col.strip() for col in df_raw.columns]
    print("--- DATASET PROFILE ---")
    print(f"Total Rows: {len(df_raw)}")
    print(f"Total Columns: {len(df_raw.columns)}")
    print("\n--- Column-wise Unique Values ---")
    for col in df_raw.columns:
        if df_raw[col].nunique() < 50:
            print(f"\nColumn: '{col}'")
            print("---------------------------------")
            unique_values = df_raw[col].unique().tolist()
            unique_values = ['<NaN>' if pd.isna(x) else x for x in unique_values]
            print(unique_values)
        else:
            print(f"\nColumn: '{col}' (has >50 unique values, showing a sample)")
            print("---------------------------------")
            sample_values = df_raw[col].dropna().sample(5).tolist()
            print(f"Sample values: {sample_values}")

except FileNotFoundError:
    print(f"FATAL ERROR: The file '{file_path}' was not found. Please check the name and location.")
    insider_df = pd.DataFrame()
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Successfully loaded the dataset.
# The dataset has 51881 rows and 18 columns.
# First 5 rows of the data:
#   SYMBOL \n                                      COMPANY \n  \
# 0       M&M                     Mahindra & Mahindra Limited
# 1       M&M                     Mahindra & Mahindra Limited
# 2       M&M                     Mahindra & Mahindra Limited
# 3    M&MFIN  Mahindra & Mahindra Financial Services Limited
# 4       IKS          Inventurus Knowledge Solutions Limited
#
#                     NAME OF THE ACQUIRER/DISPOSER \n  \
# 0  Mahindra & Mahindra Employees' Stock Option Trust
# 1                                         Alok Kumar
# 2                                       Ninad Butala
# 3  Mahindra & Mahindra Financial Services Limited...
# 4                                    Dinesh Rijhwani
#
#             CATEGORY OF PERSON \n TYPE OF SECURITY (PRIOR) \n  \
# 0                           Other               Equity Shares
# 1  Employees/Designated Employees               Equity Shares
# 2  Employees/Designated Employees               Equity Shares
# 3                           Other               Equity Shares
# 4                               -               Equity Shares
#
#   NO. OF SECURITY (PRIOR) \n  % SHAREHOLDING (PRIOR) \n  \
# 0                   42531238                       3.42
# 1                      29413                       0.00
# 2                        Nil                       0.00
# 3                     637542                       0.05
# 4                      12000                       0.01
#
#    NO. OF SECURITIES (ACQUIRED/DISPLOSED) \n  \
# 0                                    10654.0
# 1                                     1524.0
# 2                                      566.0
# 3                                     5793.0
# 4                                     6000.0
#
#   VALUE OF SECURITY (ACQUIRED/DISPLOSED) \n  \
# 0                                     53270
# 1                                   4769587
# 2                                   1771382
# 3                                   1553393
# 4                                   1885800
#
#   ACQUISITION/DISPOSAL TRANSACTION TYPE \n TYPE OF SECURITY (POST) \n  \
# 0                                     Sell              Equity Shares
# 1                                      Buy              Equity Shares
# 2                                      Buy              Equity Shares
# 3                                     Sell              Equity Shares
# 4                                      Buy              Equity Shares
#
#   NO. OF SECURITY (POST) \n % POST \n DATE OF ALLOTMENT/ACQUISITION FROM \n  \
# 0                  42520584      3.42                             15-Jul-25
# 1                     30937         0                             15-Jul-25
# 2                       566         0                             15-Jul-25
# 3                    631749      0.05                             14-Jul-25
# 4                     18000      0.01                             14-Jul-25
#
#   DATE OF ALLOTMENT/ACQUISITION TO \n DATE OF INTIMATION TO COMPANY \n  \
# 0                           15-Jul-25                        15-Jul-25
# 1                           15-Jul-25                        15-Jul-25
# 2                           15-Jul-25                        15-Jul-25
# 3                           14-Jul-25                        15-Jul-25
# 4                           14-Jul-25                        14-Jul-25
#
#   MODE OF ACQUISITION \n EXCHANGE \n
# 0                   ESOP         NaN
# 1                   ESOP         NaN
# 2                   ESOP         NaN
# 3                   ESOP         NaN
# 4                   ESOP         NaN
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51881 entries, 0 to 51880
# Data columns (total 18 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   SYMBOL
#                                   51881 non-null  object
#  1   COMPANY
#                                  51881 non-null  object
#  2   NAME OF THE ACQUIRER/DISPOSER
#            51881 non-null  object
#  3   CATEGORY OF PERSON
#                       51881 non-null  object
#  4   TYPE OF SECURITY (PRIOR)
#                 51774 non-null  object
#  5   NO. OF SECURITY (PRIOR)
#                  51881 non-null  object
#  6   % SHAREHOLDING (PRIOR)
#                   51881 non-null  float64
#  7   NO. OF SECURITIES (ACQUIRED/DISPLOSED)
#   51806 non-null  float64
#  8   VALUE OF SECURITY (ACQUIRED/DISPLOSED)
#   51881 non-null  object
#  9   ACQUISITION/DISPOSAL TRANSACTION TYPE
#    51881 non-null  object
#  10  TYPE OF SECURITY (POST)
#                  51881 non-null  object
#  11  NO. OF SECURITY (POST)
#                   51881 non-null  object
#  12  % POST
#                                   51881 non-null  object
#  13  DATE OF ALLOTMENT/ACQUISITION FROM
#       51881 non-null  object
#  14  DATE OF ALLOTMENT/ACQUISITION TO
#         51881 non-null  object
#  15  DATE OF INTIMATION TO COMPANY
#            51881 non-null  object
#  16  MODE OF ACQUISITION
#                      51881 non-null  object
#  17  EXCHANGE
#                                 33136 non-null  object
# dtypes: float64(2), object(16)
# memory usage: 7.1+ MB
# --- DATASET PROFILE ---
# Total Rows: 51881
# Total Columns: 18
#
# --- Column-wise Unique Values ---
#
# Column: 'SYMBOL' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['SALZERELEC', 'AJOONI', 'BSOFT', 'MAHICKRA', 'INFY']
#
# Column: 'COMPANY' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['Indusind Bank Limited', 'Indusind Bank Limited', 'Sammaan Capital Limited', 'Khaitan Chemicals & Fertilizers Limited', 'Dr. Lal Path Labs Ltd.']
#
# Column: 'NAME OF THE ACQUIRER/DISPOSER' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['Niyogi Enterprise Private Limited', 'Preeti Gautam Shah', 'VINEET', 'MAYURESH V APTE', 'JEEVAN PRAKASH']
#
# Column: 'CATEGORY OF PERSON'
# ---------------------------------
# ['Other', 'Employees/Designated Employees', '-', 'Promoters', 'Key Managerial Personnel', 'Promoter Group', 'Director', 'Immediate relative', 'Connected Person']
#
# Column: 'TYPE OF SECURITY (PRIOR)'
# ---------------------------------
# ['Equity Shares', 'Warrants', 'Preference Shares', '<NaN>', 'ADR/GDR/FCCB', 'Debentures', 'Convertible preference shares', 'Convertible Debenture']
#
# Column: 'NO. OF SECURITY (PRIOR)' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['Nil', '1953500', '3398054', 'Nil', '339000']
#
# Column: '% SHAREHOLDING (PRIOR)' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: [1.9, 0.36, 0.12, 0.48, 0.02]
#
# Column: 'NO. OF SECURITIES (ACQUIRED/DISPLOSED)' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: [606015.0, 16000.0, 500.0, 29772.0, 180000.0]
#
# Column: 'VALUE OF SECURITY (ACQUIRED/DISPLOSED)' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['1552000', '6033168', '78207500', '1430000', '1487444']
#
# Column: 'ACQUISITION/DISPOSAL TRANSACTION TYPE'
# ---------------------------------
# ['Sell', 'Buy', 'Pledge', 'Pledge Invoke', 'Pledge Revoke', '-']
#
# Column: 'TYPE OF SECURITY (POST)'
# ---------------------------------
# ['Equity Shares', 'Warrants', 'Preference Shares', '-', 'ADR/GDR/FCCB', 'Debentures', 'Convertible preference shares', 'Convertible Debenture']
#
# Column: 'NO. OF SECURITY (POST)' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['4232', '544928', '3300', '2238069', '29016791']
#
# Column: '% POST' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['0', '0', '0.28', '0.02', '0']
#
# Column: 'DATE OF ALLOTMENT/ACQUISITION FROM' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['17-Sep-24', '21-Feb-24', '01-Feb-23', '06-Jan-23', '19-Dec-22']
#
# Column: 'DATE OF ALLOTMENT/ACQUISITION TO' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['27-Mar-24', '29-Apr-24', '28-Jun-24', '13-Jun-23', '20-Oct-22']
#
# Column: 'DATE OF INTIMATION TO COMPANY' (has >50 unique values, showing a sample)
# ---------------------------------
# Sample values: ['16-Aug-23', '21-Sep-22', '29-Nov-23', '-', '20-Mar-25']
#
# Column: 'MODE OF ACQUISITION'
# ---------------------------------
# ['ESOP', 'Market Purchase', 'Off Market', 'Market Sale', 'Conversion of security', 'Pledge Creation', 'Invocation of pledge', 'Gift', '-', 'Others', 'Public Right', 'Preferential Offer', 'Inter-se-Transfer', 'Revokation of Pledge', 'Scheme of Amalgamation/Merger/Demerger/Arrangement', 'Bonus']
#
# Column: 'EXCHANGE'
# ---------------------------------
# ['<NaN>', 'NSE', '-', 'BSE', 'BSE,NSE', 'MSEI', 'MA', 'na']

# %%
# Step 2: Clean the Data 
if not insider_df.empty:
    print(f"--- SCRIPT START ---")
    print(f"Successfully loaded '{file_path}'. Initial dataset has {len(insider_df)} rows.")
    insider_df.columns = [col.strip() for col in insider_df.columns]
    column_map = {
        'SYMBOL': 'symbol', 'COMPANY': 'company_name', 'NAME OF THE ACQUIRER/DISPOSER': 'insider_name',
        'CATEGORY OF PERSON': 'insider_category', 'NO. OF SECURITIES (ACQUIRED/DISPLOSED)': 'quantity',
        'VALUE OF SECURITY (ACQUIRED/DISPLOSED)': 'value', 'ACQUISITION/DISPOSAL TRANSACTION TYPE': 'transaction_type',
        '% POST': 'post_holding_pct', 'DATE OF ALLOTMENT/ACQUISITION FROM': 'transaction_date',
        'DATE OF INTIMATION TO COMPANY': 'broadcast_date', 'MODE OF ACQUISITION': 'mode'
    }
    insider_df.rename(columns=column_map, inplace=True)
    final_columns = [
        'symbol', 'company_name', 'insider_name', 'insider_category', 'quantity', 'value', 
        'transaction_type', 'post_holding_pct', 'transaction_date', 'broadcast_date', 'mode'
    ]
    existing_columns = [col for col in final_columns if col in insider_df.columns]
    insider_df = insider_df[existing_columns].copy()

    insider_df.replace(['-', 'Nil'], np.nan, inplace=True)
    insider_df['transaction_date'] = pd.to_datetime(insider_df['transaction_date'], errors='coerce', dayfirst=True)
    insider_df['broadcast_date'] = pd.to_datetime(insider_df['broadcast_date'], errors='coerce', dayfirst=True)
    for col in ['value', 'quantity', 'post_holding_pct']:
        insider_df[col] = pd.to_numeric(insider_df[col].astype(str).str.replace(',', '', regex=False), errors='coerce')
    print(f"Rows after initial cleaning & type conversion: {len(insider_df)}")

    insider_df.dropna(subset=['symbol', 'transaction_date', 'broadcast_date', 'quantity', 'value', 'transaction_type'], inplace=True)
    print(f"Rows after dropping critical NaNs: {len(insider_df)}")

    insider_df = insider_df[(insider_df['quantity'] > 0) & (insider_df['value'] > 0)]
    insider_df['price'] = insider_df['value'] / insider_df['quantity']
    insider_df = insider_df[(insider_df['price'] > 0) & np.isfinite(insider_df['price'])]
    print(f"Rows after filtering for valid trades: {len(insider_df)}")

    insider_df = insider_df[insider_df['transaction_type'].isin(['Buy', 'Sell'])]
    print(f"Rows after keeping only 'Buy'/'Sell' transactions: {len(insider_df)}")

    high_signal_categories = ['Promoters', 'Director', 'Promoter Group', 'Employees']  # Relaxed: Added 'Employees'
    insider_df = insider_df[insider_df['insider_category'].isin(high_signal_categories)]
    print(f"Rows after filtering for high-signal categories: {len(insider_df)}")

    market_transactions = ['Market Purchase', 'Market Sale']
    insider_df = insider_df[insider_df['mode'].isin(market_transactions)]
    print(f"Rows after filtering for Market Purchases/Sales: {len(insider_df)}")

    # Relaxed insider filter: >=1 unique insiders
    insider_df = insider_df.groupby(['symbol', 'broadcast_date']).filter(lambda x: len(x['insider_name'].unique()) >= 1).reset_index(drop=True)
    print(f"Rows after relaxed insider filtering: {len(insider_df)}")

    insider_df.sort_values(by='broadcast_date', inplace=True)
    insider_df.drop_duplicates(inplace=True)
    insider_df.reset_index(drop=True, inplace=True)
    print(f"\n--- Data Cleaning Complete ---")
    print(f"Final cleaned dataset has {len(insider_df)} rows.")

    cleaned_file_path = 'cleaned_insider_data.csv'
    insider_df.to_csv(cleaned_file_path, index=False)
    print(f"Cleaned data saved to '{cleaned_file_path}'.")

    if not insider_df.empty:
        print("\nFinal Cleaned Data Head:")
        print(insider_df.head())
        print("\nFinal Cleaned Data Info:")
        insider_df.info()
    else:
        print("\nWarning: The final DataFrame is empty. Check the row counts at each step.")
# Out:
# --- SCRIPT START ---
# Successfully loaded 'C:\Users\DELL\Downloads\raw_nse_insider.csv'. Initial dataset has 51881 rows.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_67672\3174562842.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   insider_df['transaction_date'] = pd.to_datetime(insider_df['transaction_date'], errors='coerce', dayfirst=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_67672\3174562842.py:23: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   insider_df['broadcast_date'] = pd.to_datetime(insider_df['broadcast_date'], errors='coerce', dayfirst=True)
# Rows after initial cleaning & type conversion: 51881
# Rows after dropping critical NaNs: 51667
# Rows after filtering for valid trades: 49490
# Rows after keeping only 'Buy'/'Sell' transactions: 45327
# Rows after filtering for high-signal categories: 16332
# Rows after filtering for Market Purchases/Sales: 12944
# Rows after relaxed insider filtering: 12944
#
# --- Data Cleaning Complete ---
# Final cleaned dataset has 12728 rows.
# Cleaned data saved to 'cleaned_insider_data.csv'.
#
# Final Cleaned Data Head:
#        symbol                        company_name  \
# 0    CONFIPET  Confidence Petroleum India Limited
# 1     ALMONDZ   Almondz Global Securities Limited
# 2    ARMANFIN    Arman Financial Services Limited
# 3  MAHSEAMLES        Maharashtra Seamless Limited
# 4   VINEETLAB         Vineet Laboratories Limited
#
#                                  insider_name insider_category  quantity  \
# 0         Essenn LPG Bottling Private Limited   Promoter Group  486359.0
# 1  Avonmore Capital & Management Services Ltd        Promoters     300.0
# 2                         Himani A Manakiwala        Promoters    3037.0
# 3                                SAKET JINDAL        Promoters    9550.0
# 4                         Venkata Rama Gaddam        Promoters    7000.0
#
#         value transaction_type  post_holding_pct transaction_date  \
# 0  10122899.0              Buy              1.71       2020-09-22
# 1     22725.0              Buy             58.24       2021-11-23
# 2   4405563.0             Sell              0.11       2022-02-20
# 3   3490762.0              Buy              3.30       2023-03-10
# 4    300901.0              Buy              5.91       2022-03-16
#
#   broadcast_date             mode        price
# 0     2020-10-01  Market Purchase    20.813636
# 1     2021-11-24  Market Purchase    75.750000
# 2     2022-02-21      Market Sale  1450.629898
# 3     2022-03-13  Market Purchase   365.524817
# 4     2022-03-18  Market Purchase    42.985857
#
# Final Cleaned Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12728 entries, 0 to 12727
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symbol            12728 non-null  object
#  1   company_name      12728 non-null  object
#  2   insider_name      12725 non-null  object
#  3   insider_category  12728 non-null  object
#  4   quantity          12728 non-null  float64
#  5   value             12728 non-null  float64
#  6   transaction_type  12728 non-null  object
#  7   post_holding_pct  12725 non-null  float64
#  8   transaction_date  12728 non-null  datetime64[ns]
#  9   broadcast_date    12728 non-null  datetime64[ns]
#  10  mode              12728 non-null  object
#  11  price             12728 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(6)
# memory usage: 1.2+ MB

# %%
# Step 3: Enrich Data with Relaxed Filters
try:
    insider_df = pd.read_csv('cleaned_insider_data.csv', parse_dates=['transaction_date', 'broadcast_date'])
    print(f"Successfully loaded 'cleaned_insider_data.csv' with {len(insider_df)} rows.")
except FileNotFoundError:
    print("FATAL ERROR: 'cleaned_insider_data.csv' not found. Please run the cleaning script first.")
    insider_df = pd.DataFrame()

print("Downloading Nifty 50 data from yfinance...")
try:
    start_date = insider_df['broadcast_date'].min() - pd.Timedelta(days=90)
    end_date = insider_df['broadcast_date'].max()
    nifty_df = yf.download('^NSEI', start=start_date, end=end_date, auto_adjust=False)
    nifty_df.index.name = 'Date'
    nifty_df['nifty_returns'] = nifty_df['Adj Close'].pct_change()
    print("Successfully downloaded Nifty 50 benchmark data.")
except Exception as e:
    print(f"FATAL ERROR: Could not download Nifty 50 data. Error: {e}")
    nifty_df = pd.DataFrame()

def sanity_check_price_data(df, ticker_name):
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.droplevel(1)
    required_cols = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
    if not all(col in df.columns for col in required_cols):
        print(f"  - Sanity check failed: Missing required columns for {ticker_name}.")
        return None
    df.ffill(inplace=True)
    price_cols = ['Open', 'High', 'Low', 'Close', 'Adj Close']
    df[price_cols] = df[price_cols].replace(0, np.nan).ffill()
    df.dropna(subset=price_cols, inplace=True)
    return df

def calculate_market_metrics(stock_df, nifty_df, ticker):
    stock_df['returns'] = stock_df['Adj Close'].pct_change()
    high_low = stock_df['High'] - stock_df['Low']
    high_prev_close = np.abs(stock_df['High'] - stock_df['Adj Close'].shift())
    low_prev_close = np.abs(stock_df['Low'] - stock_df['Adj Close'].shift())
    tr = pd.concat([high_low, high_prev_close, low_prev_close], axis=1).max(axis=1)
    stock_df['atr_10'] = tr.rolling(window=10).mean()
    stock_df['daily_value'] = stock_df['Adj Close'] * stock_df['Volume']
    stock_df['adv_10'] = stock_df['daily_value'].rolling(window=10).mean()
    stock_df['volatility_60'] = stock_df['returns'].rolling(window=60).std() * np.sqrt(252)  # Changed to 60 for consistency
    combined_returns = pd.concat([stock_df['returns'], nifty_df['nifty_returns']], axis=1).dropna()
    rolling_cov = combined_returns['returns'].rolling(window=60).cov(combined_returns['nifty_returns'])
    rolling_var = combined_returns['nifty_returns'].rolling(window=60).var()
    stock_df['beta_60'] = rolling_cov / rolling_var
    
    try:
        market_cap = yf.Ticker(ticker).info.get('marketCap', 0) / 10000000  # In Cr
        stock_df['market_cap_cr'] = market_cap
    except:
        stock_df['market_cap_cr'] = 0
    
    return stock_df[['atr_10', 'adv_10', 'volatility_60', 'beta_60', 'market_cap_cr']]

if not insider_df.empty and not nifty_df.empty:
    print("\nStarting data enrichment process...")
    unique_symbols = insider_df['symbol'].unique()
    # For testing: Reduce to a sample for faster iteration
    # unique_symbols = unique_symbols[:50]  # Uncomment to sample 50 symbols

    # Caching: Check for cached price data
    cache_file = 'price_data_cache.pkl'
    if os.path.exists(cache_file):
        print("Loading cached price data...")
        with open(cache_file, 'rb') as f:
            all_price_data = pickle.load(f)
    else:
        print("Downloading batched price data for all symbols...")
        tickers = [f"{s}.NS" for s in unique_symbols] + [f"{s}.BO" for s in unique_symbols]  # Include both suffixes
        all_price_data = yf.download(tickers, start=start_date, end=end_date, auto_adjust=False, progress=True, group_by='ticker')
        with open(cache_file, 'wb') as f:
            pickle.dump(all_price_data, f)
        print("Cached price data saved.")

    def process_symbol(symbol):
        try:
            # Try .NS first, then .BO
            ticker_ns = f'{symbol}.NS'
            if ticker_ns in all_price_data:
                stock_df_raw = all_price_data[ticker_ns]
            else:
                ticker_bo = f'{symbol}.BO'
                if ticker_bo in all_price_data:
                    stock_df_raw = all_price_data[ticker_bo]
                    ticker_ns = ticker_bo
                else:
                    return None

            if stock_df_raw.empty:
                return None

            stock_df = sanity_check_price_data(stock_df_raw.copy(), symbol)
            if stock_df is None or stock_df.empty:
                return None

            metrics_df = calculate_market_metrics(stock_df, nifty_df, ticker_ns)
            
            trades_for_symbol = insider_df[insider_df['symbol'] == symbol].copy()
            enriched_trades = pd.merge_asof(
                trades_for_symbol.sort_values('broadcast_date'),
                metrics_df.sort_index(),
                left_on='broadcast_date',
                right_index=True,
                direction='backward'
            )
            return enriched_trades
        except Exception as e:
            print(f"  - An unexpected error occurred for {symbol}: {e}")
            return None

    # Parallel processing
    all_enriched_trades = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(process_symbol, unique_symbols))
        all_enriched_trades = [res for res in results if res is not None]

    if all_enriched_trades:
        enriched_df = pd.concat(all_enriched_trades, ignore_index=True)
        enriched_df.dropna(subset=['atr_10', 'adv_10', 'volatility_60', 'beta_60', 'market_cap_cr'], inplace=True)
        final_file_path = 'backtest_ready_data.csv'
        enriched_df.to_csv(final_file_path, index=False)
        print("\n--- Data Enrichment Complete ---")
        print(f"Final dataset ready for back-testing has {len(enriched_df)} rows.")
        print(f"Saved to '{final_file_path}'.")
        print("\nFinal Enriched Data Head:")
        print(enriched_df.head())
    else:
        print("\nCould not enrich any data. Please check for errors.")
# Out:
# Successfully loaded 'cleaned_insider_data.csv' with 12728 rows.
# Downloading Nifty 50 data from yfinance...
# *********************100%***********************]  1 of 1 completed
# Successfully downloaded Nifty 50 benchmark data.
#
# Starting data enrichment process...
# Loading cached price data...
#
# --- Data Enrichment Complete ---
# Final dataset ready for back-testing has 12297 rows.
# Saved to 'backtest_ready_data.csv'.
#
# Final Enriched Data Head:
#      symbol                        company_name  \
# 1  CONFIPET  Confidence Petroleum India Limited
# 2  CONFIPET  Confidence Petroleum India Limited
# 3  CONFIPET  Confidence Petroleum India Limited
# 4  CONFIPET  Confidence Petroleum India Limited
# 5  CONFIPET  Confidence Petroleum India Limited
#
#                               insider_name insider_category  quantity  \
# 1      ESSENN LPG BOTTLING PRIVATE LIMITED   Promoter Group  153000.0
# 2  CONFIDENCE LPG BOTTLING PRIVATE LIMITED   Promoter Group  605584.0
# 3  CONFIDENCE LPG BOTTLING PRIVATE LIMITED   Promoter Group   26000.0
# 4  CONFIDENCE LPG BOTTLING PRIVATE LIMITED   Promoter Group  100000.0
# 5  CONFIDENCE LPG BOTTLING PRIVATE LIMITED   Promoter Group  520000.0
#
#         value transaction_type  post_holding_pct transaction_date  \
# 1   9508950.0              Buy              6.84       2022-08-19
# 2  37118847.0              Buy              2.45       2022-08-18
# 3   2000400.0              Buy              2.46       2022-09-05
# 4   7110000.0              Buy              2.50       2022-09-28
# 5  39343200.0              Buy              2.68       2022-12-09
#
#   broadcast_date             mode      price    atr_10        adv_10  \
# 1     2022-08-22  Market Purchase  62.150000  2.704178  5.268390e+07
# 2     2022-08-24  Market Purchase  61.294299  3.097652  7.275543e+07
# 3     2022-09-24  Market Purchase  76.938462  3.572191  1.216354e+08
# 4     2022-09-30  Market Purchase  71.100000  2.859508  6.259464e+07
# 5     2022-12-12  Market Purchase  75.660000  3.009095  7.688562e+07
#
#    volatility_60   beta_60  market_cap_cr
# 1       0.446164  0.506739    1855.499059
# 2       0.465404  0.696786    1855.499059
# 3       0.483138  0.510224    1855.499059
# 4       0.481310  0.595516    1855.499059
# 5       0.397961  0.672410    1855.499059

# %%
# Step 4: Load Enriched Data and Display Info
df = pd.read_csv('backtest_ready_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12297 entries, 0 to 12296
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symbol            12297 non-null  object
#  1   company_name      12297 non-null  object
#  2   insider_name      12294 non-null  object
#  3   insider_category  12297 non-null  object
#  4   quantity          12297 non-null  float64
#  5   value             12297 non-null  float64
#  6   transaction_type  12297 non-null  object
#  7   post_holding_pct  12294 non-null  float64
#  8   transaction_date  12297 non-null  object
#  9   broadcast_date    12297 non-null  object
#  10  mode              12297 non-null  object
#  11  price             12297 non-null  float64
#  12  atr_10            12297 non-null  float64
#  13  adv_10            12297 non-null  float64
#  14  volatility_60     12297 non-null  float64
#  15  beta_60           12297 non-null  float64
#  16  market_cap_cr     12297 non-null  float64
# dtypes: float64(9), object(8)
# memory usage: 1.6+ MB

# %%
# Step 5: Backtest with Adjustments 
start_time = time.time()

try:
    data_df = pd.read_csv('backtest_ready_data.csv', parse_dates=['broadcast_date'])
    data_df['broadcast_date'] = data_df['broadcast_date'].dt.normalize()
    print(f"Loaded 'backtest_ready_data.csv' with {len(data_df)} rows.")
except FileNotFoundError:
    print("FATAL ERROR: 'backtest_ready_data.csv' not found. Exiting.")
    data_df = pd.DataFrame()

if not data_df.empty:
    initial_capital = 10000000
    max_active_positions = 20  
    transaction_cost_pct = 0.001  
    historical_events_lookback = 1  
    momentum_decay_min_hold_days = 20  
    risk_free_rate = 0.05  

    cash = initial_capital
    holdings = {}
    trade_log = []

    print("\nFetching all required price data...")
    sim_start_date = data_df['broadcast_date'].min() - pd.Timedelta(days=180)
    sim_end_date = data_df['broadcast_date'].max() + pd.Timedelta(days=60)
    unique_symbols = data_df['symbol'].unique()
    tickers_ns = [f"{s}.NS" for s in unique_symbols]
    all_price_data = yf.download(tickers_ns, start=sim_start_date, end=sim_end_date, auto_adjust=False, progress=True, group_by='ticker')

    price_data_cache = {}
    for symbol in unique_symbols:
        try:
            symbol_data = all_price_data[f"{symbol}.NS"]
            if not symbol_data.dropna().empty:
                price_data_cache[symbol] = symbol_data
        except KeyError:
            continue
    print(f"Successfully fetched and cached price data for {len(price_data_cache)} symbols.")

    print("Finding all potential historical signals...")
    all_signals = []
    for symbol, group in data_df.groupby('symbol'):
        daily_buys = group[group['transaction_type'] == 'Buy'].groupby('broadcast_date').filter(lambda x: len(x['insider_name'].unique()) >= 1)  # Relaxed to >=1
        signal_dates = daily_buys['broadcast_date'].unique()
        for date in signal_dates:
            tech_data = group[group['broadcast_date'] == date].iloc[0]
            all_signals.append({
                'date': date, 
                'symbol': symbol,
                'atr_10': tech_data.get('atr_10', 0.02),
                'adv_10': tech_data.get('adv_10', 10000000),
                'beta_60': tech_data.get('beta_60', 1.0),
                'volatility_60': tech_data.get('volatility_60', 0.2)
            })
    signal_df = pd.DataFrame(all_signals).sort_values('date').reset_index(drop=True)
    print(f"Identified {len(signal_df)} potential signal events across history.")

    sim_dates = pd.date_range(start=data_df['broadcast_date'].min(), end=sim_end_date)

    # Initialize equity curve
    equity_curve = pd.Series(index=sim_dates, dtype=float)

    for current_date in sim_dates:
        current_portfolio_value = cash
        for symbol, pos in holdings.items():
            stock_data = price_data_cache.get(symbol)
            if stock_data is not None and current_date in stock_data.index:
                current_portfolio_value += pos['shares'] * stock_data.loc[current_date, 'Close']
            else:
                current_portfolio_value += pos['shares'] * pos['entry_price']

        # Record equity for this date
        equity_curve[current_date] = current_portfolio_value

        for symbol, pos in list(holdings.items()):
            stock_data = price_data_cache.get(symbol)
            if stock_data is not None and current_date in stock_data.index:
                latest_price = stock_data.loc[current_date, 'Close']
                exit_reason = None
                if latest_price > pos['peak_price']:
                    pos['peak_price'] = latest_price
                    pos['date_of_peak_price'] = current_date
                
                trailing_stop = pos['peak_price'] - (1.5 * pos['atr_10'])  
                no_new_high_days = 25 if pos['volatility_60'] < 0.25 else 15  
                
                if latest_price >= pos['profit_target']:
                    exit_reason = "Profit Target"
                elif latest_price <= pos['stop_loss']:
                    exit_reason = "Stop Loss"
                elif (current_date - pos['entry_date']).days > 120:  
                    exit_reason = "Max Hold Exceeded"
                elif (current_date - pos['entry_date']).days > momentum_decay_min_hold_days and \
                     (current_date - pos['date_of_peak_price']).days > no_new_high_days:
                    exit_reason = "Momentum Decay"
                if exit_reason:
                    exit_value = (pos['shares'] * latest_price) * (1 - transaction_cost_pct)
                    cash += exit_value  
                    trade_log.append({
                        'Symbol': symbol,
                        'Entry Date': pos['entry_date'],
                        'Entry Price': pos['entry_price'],
                        'Exit Date': current_date,
                        'Exit Price': latest_price,
                        'Return (%)': ((latest_price / pos['entry_price']) - 1) * 100,
                        'Exit Reason': exit_reason,
                        'ATR': pos.get('atr_10', 0.02),
                        'Beta': pos.get('beta_60', 1.0),
                        'Volatility': pos.get('volatility_60', 0.2),
                        'ADV_Cr': pos.get('adv_10', 10000000) / 10000000
                    })
                    del holdings[symbol]

        todays_signals = signal_df[signal_df['date'] == current_date]
        if len(holdings) >= max_active_positions or todays_signals.empty:
            continue

        for _, signal in todays_signals.iterrows():
            symbol = signal['symbol']
            if symbol in holdings: continue
            historical_signals = signal_df[(signal_df['symbol'] == symbol) & (signal_df['date'] < current_date)]
            if len(historical_signals) < 1: continue  # Relaxed to >=1
            stock_data = price_data_cache.get(symbol)
            if stock_data is None: continue
            returns, volatilities = [], []
            for _, past_signal in historical_signals.tail(historical_events_lookback).iterrows():
                entry_date = past_signal['date'] + pd.Timedelta(days=1)
                exit_date = entry_date + pd.Timedelta(days=30)
                if entry_date in stock_data.index and exit_date in stock_data.index:
                    entry_price = stock_data.loc[entry_date, 'Open']
                    price_series = stock_data.loc[entry_date:exit_date, 'Close']
                    if entry_price > 0:
                        returns.append((price_series.iloc[-1] / entry_price) - 1)
                        volatilities.append(price_series.pct_change().std())
            if not returns or not volatilities: continue
            avg_return, avg_vol = np.mean(returns), np.mean(volatilities)
            if avg_return < -0.02:  # Less strict
                continue
            historical_win_rate = sum(1 for r in returns if r > 0) / len(returns) if returns else 0
            if historical_win_rate < 0.30:  # Lowered threshold
                print(f"  -> SKIPPED: {symbol} - Poor win rate: {historical_win_rate:.1%}")
                continue
            entry_date = current_date + pd.Timedelta(days=1)
            if entry_date not in stock_data.index: continue
            entry_price = stock_data.loc[entry_date, 'Open']
            if entry_price <= 0: continue
            profit_target_price = entry_price * (1 + max(avg_return, 0.15))  
            stop_loss_price = entry_price * (1 - (avg_vol * 4))  
            position_alloc = 0.05 if signal['beta_60'] > 1.5 else 0.08  
            position_size = current_portfolio_value * position_alloc
            shares_to_buy = position_size / entry_price
            trade_cost = shares_to_buy * entry_price * (1 + transaction_cost_pct)
            if cash >= trade_cost:
                cash -= trade_cost
                holdings[symbol] = {
                    'shares': shares_to_buy, 'entry_price': entry_price, 'entry_date': entry_date,
                    'profit_target': profit_target_price, 'stop_loss': stop_loss_price,
                    'peak_price': entry_price, 'date_of_peak_price': entry_date,
                    'atr_10': signal['atr_10'], 'beta_60': signal['beta_60'], 
                    'volatility_60': signal['volatility_60'], 'adv_10': signal['adv_10']
                }
                print(f"  -> TRADE: BUY {symbol} on {entry_date.date()} at {entry_price:.2f}")
                print(f"     -> Win Rate: {historical_win_rate:.1%}, Target: {profit_target_price:.2f}, Stop: {stop_loss_price:.2f}")
                if len(holdings) >= max_active_positions: break

 
    print("BACKTEST SIMULATION COMPLETE")
    end_time = time.time()
    print(f"Total execution time: {end_time - start_time:.2f} seconds.")

    if not trade_log:
        print("\nNo trades were executed. Final metrics cannot be calculated.")
    else:
        trade_log_df = pd.DataFrame(trade_log)
        print("\n--- Technical Indicators Summary ---")
        print(f"Average ATR: {trade_log_df['ATR'].mean():.3f}")
        print(f"Average Beta: {trade_log_df['Beta'].mean():.2f}")
        print(f"Average Volatility: {trade_log_df['Volatility'].mean():.3f}")
        print(f"Average ADV: {trade_log_df['ADV_Cr'].mean():.1f} Crores")

        print("\nPer-Stock Performance")

        def calculate_trade_drawdown(row):
            symbol, start, end = row['Symbol'], row['Entry Date'], row['Exit Date']
            if symbol not in price_data_cache or start not in price_data_cache[symbol].index or end not in price_data_cache[symbol].index:
                return 0
            prices = price_data_cache[symbol].loc[start:end, 'Close']
            if prices.empty: return 0
            peak = prices.cummax()
            drawdown = (prices / peak) - 1
            return drawdown.min() * 100

        trade_log_df['Max Drawdown (%)'] = trade_log_df.apply(calculate_trade_drawdown, axis=1)

        def profit_factor(s):
            wins = s[s > 0].sum()
            losses = np.abs(s[s < 0].sum())
            return wins / losses if losses > 0 else np.inf

        def trade_sharpe(s):
            if s.std() == 0 or len(s) < 2: return np.nan
            return s.mean() / s.std()

        stock_stats = trade_log_df.groupby('Symbol').agg(
            num_trades=('Symbol', 'size'),
            win_rate_pct=('Return (%)', lambda s: (s > 0).mean() * 100),
            avg_return_pct=('Return (%)', 'mean'),
            profit_factor=('Return (%)', profit_factor),
            avg_drawdown_pct=('Max Drawdown (%)', 'mean'),
            trade_sharpe=('Return (%)', trade_sharpe)
        ).sort_values('num_trades', ascending=False)

        stock_stats_display = stock_stats.copy()
        for col in ['win_rate_pct', 'avg_return_pct', 'avg_drawdown_pct']:
            stock_stats_display[col] = stock_stats_display[col].map('{:.2f}%'.format)
        for col in ['profit_factor', 'trade_sharpe']:
            stock_stats_display[col] = stock_stats_display[col].map('{:.2f}'.format)
        print(stock_stats_display.to_string())

        print("\n--- Detailed Trade Log ---")
        trade_log_df_display = trade_log_df.copy()
        trade_log_df_display['Entry Date'] = trade_log_df_display['Entry Date'].dt.date
        trade_log_df_display['Exit Date'] = trade_log_df_display['Exit Date'].dt.date
        trade_log_df_display['Entry Price'] = trade_log_df_display['Entry Price'].map('{:,.2f}'.format)
        trade_log_df_display['Exit Price'] = trade_log_df_display['Exit Price'].map('{:,.2f}'.format)
        trade_log_df_display['Return (%)'] = trade_log_df_display['Return (%)'].map('{:.2f}%'.format)
        trade_log_df_display['ATR'] = trade_log_df_display['ATR'].map('{:.3f}'.format)
        trade_log_df_display['Beta'] = trade_log_df_display['Beta'].map('{:.2f}'.format)
        display_columns = ['Symbol', 'Entry Date', 'Entry Price', 'Exit Date', 'Exit Price', 'Return (%)', 'Exit Reason', 'ATR', 'Beta']
        print(trade_log_df_display.to_string(columns=display_columns, index=False))

        # Add holding days to trade_log_df (for time adjustment)
        trade_log_df['holding_days'] = (trade_log_df['Exit Date'] - trade_log_df['Entry Date']).dt.days
        trade_log_df['holding_days'] = trade_log_df['holding_days'].clip(lower=1)  # Avoid division by zero
        
        total_return = (cash / initial_capital) - 1  # Use the final 'cash' value from backtest
        
        # CAGR (annualized over backtest span)
        if not trade_log_df.empty:
            first_entry = trade_log_df['Entry Date'].min()
            last_exit = trade_log_df['Exit Date'].max()
            years_span = (last_exit - first_entry).days / 365.25
            years_span = max(years_span, 1)  # Avoid issues with short spans
            cagr = (cash / initial_capital) ** (1 / years_span) - 1
        else:
            cagr = 0
        
        # Geometric Mean Return (compounded average per trade, for reference)
        geo_mean_return = (np.prod(1 + trade_log_df['Return (%)'] / 100) ** (1 / len(trade_log_df)) - 1) * 100 if not trade_log_df.empty else 0
        
        # Equity Curve-Based Metrics
        equity_curve = equity_curve.ffill().dropna()  # Fill any gaps
        daily_returns = equity_curve.pct_change().dropna()  # Daily % changes
        
        # Annualized Return (CAGR from equity curve, already calculated above, but confirm)
        mean_annual_return = (1 + daily_returns.mean()) ** 252 - 1
        
        # Downside Deviation for Sortino
        downside_returns = daily_returns[daily_returns < 0]
        downside_dev = downside_returns.std() * np.sqrt(252) if not downside_returns.empty else 0
        
        # Mean Annualized Excess Return
        mean_annual_excess = mean_annual_return - risk_free_rate
        
        # Sortino Ratio
        overall_sortino = mean_annual_excess / downside_dev if downside_dev > 0 else 0
        
        # Maximum Drawdown for Calmar
        rolling_max = equity_curve.cummax()
        drawdowns = (equity_curve / rolling_max) - 1
        max_drawdown = drawdowns.min() * -1  # Positive value
        overall_calmar = cagr / max_drawdown if max_drawdown > 0 else 0
        
        # Print Updated Metrics
        print("\nEnhanced Strategy Performance")
        print(f"Total Trades: {len(trade_log_df)}")
        print(f"Overall Compounded Return: {total_return * 100:.2f}%")
        print(f"Compounded Annual Growth Rate (CAGR): {cagr * 100:.2f}%")
        print(f"Geometric Mean Return per Trade: {geo_mean_return:.2f}%")
        print(f"Average Holding Days: {trade_log_df['holding_days'].mean():.1f}")
        print(f"Overall Annualized Sortino Ratio: {overall_sortino:.2f}")
        print(f"Overall Annualized Calmar Ratio: {overall_calmar:.2f}")
# Out:
# Loaded 'backtest_ready_data.csv' with 12297 rows.
#
# Fetching all required price data...
# *********************100%***********************]  913 of 913 completed
# Successfully fetched and cached price data for 913 symbols.
# Finding all potential historical signals...
# Identified 4282 potential signal events across history.
#   -> TRADE: BUY MAHSEAMLES on 2022-08-02 at 367.05
#      -> Win Rate: 100.0%, Target: 422.11, Stop: 332.40
#   -> TRADE: BUY ASTEC on 2022-08-04 at 1908.60
#      -> Win Rate: 100.0%, Target: 2194.89, Stop: 1838.88
#   -> TRADE: BUY TOKYOPLAST on 2022-08-04 at 89.90
#      -> Win Rate: 100.0%, Target: 103.39, Stop: 76.64
#   -> SKIPPED: AURIONPRO - Poor win rate: 0.0%
#   -> TRADE: BUY GODREJAGRO on 2022-08-18 at 505.70
#      -> Win Rate: 100.0%, Target: 581.56, Stop: 479.28
#   -> TRADE: BUY NCLIND on 2022-08-18 at 175.00
#      -> Win Rate: 100.0%, Target: 201.25, Stop: 163.67
#   -> TRADE: BUY DBCORP on 2022-08-18 at 92.00
#      -> Win Rate: 100.0%, Target: 110.29, Stop: 78.14
#   -> TRADE: BUY CONFIPET on 2022-08-25 at 69.00
#      -> Win Rate: 100.0%, Target: 83.73, Stop: 58.52
#   -> TRADE: BUY VAIBHAVGBL on 2022-08-25 at 307.55
#      -> Win Rate: 100.0%, Target: 363.81, Stop: 262.24
#   -> TRADE: BUY JINDALSTEL on 2022-08-25 at 399.75
#      -> Win Rate: 100.0%, Target: 459.71, Stop: 366.67
#   -> TRADE: BUY BECTORFOOD on 2022-08-25 at 365.00
#      -> Win Rate: 100.0%, Target: 419.75, Stop: 332.12
#   -> TRADE: BUY VAIBHAVGBL on 2022-09-08 at 411.10
#      -> Win Rate: 100.0%, Target: 472.77, Stop: 372.26
#   -> SKIPPED: PKTEA - Poor win rate: 0.0%
#   -> TRADE: BUY STARCEMENT on 2022-09-13 at 101.30
#      -> Win Rate: 100.0%, Target: 116.50, Stop: 88.66
#   -> TRADE: BUY SASKEN on 2022-09-14 at 866.60
#      -> Win Rate: 100.0%, Target: 996.59, Stop: 793.72
#   -> TRADE: BUY DBCORP on 2022-09-15 at 142.35
#      -> Win Rate: 100.0%, Target: 163.70, Stop: 123.54
#   -> TRADE: BUY IPL on 2022-09-20 at 308.00
#      -> Win Rate: 100.0%, Target: 354.20, Stop: 273.93
#   -> SKIPPED: MAHICKRA - Poor win rate: 0.0%
#   -> TRADE: BUY ZYDUSWELL on 2022-09-29 at 1585.00
#      -> Win Rate: 100.0%, Target: 1822.75, Stop: 1494.83
#   -> TRADE: BUY CLEDUCATE on 2022-09-29 at 75.03
#      -> Win Rate: 100.0%, Target: 86.28, Stop: 65.11
#   -> TRADE: BUY VAIBHAVGBL on 2022-09-29 at 359.90
#      -> Win Rate: 100.0%, Target: 413.88, Stop: 328.76
#   -> TRADE: BUY PATINTLOG on 2022-09-29 at 13.80
#      -> Win Rate: 100.0%, Target: 15.87, Stop: 12.29
#   -> TRADE: BUY MAHSEAMLES on 2022-09-30 at 380.60
#      -> Win Rate: 100.0%, Target: 437.69, Stop: 332.63
#   -> TRADE: BUY KPIGREEN on 2022-10-28 at 85.53
#      -> Win Rate: 100.0%, Target: 98.36, Stop: 77.00
#   -> TRADE: BUY CHEMBOND on 2022-10-28 at 201.35
#      -> Win Rate: 100.0%, Target: 231.55, Stop: 178.21
#   -> TRADE: BUY GNA on 2022-11-10 at 333.10
#      -> Win Rate: 100.0%, Target: 383.07, Stop: 314.18
#   -> TRADE: BUY SDBL on 2022-11-11 at 44.49
#      -> Win Rate: 100.0%, Target: 54.95, Stop: 39.06
#   -> TRADE: BUY CHAMBLFERT on 2022-11-17 at 286.65
#      -> Win Rate: 100.0%, Target: 329.65, Stop: 270.62
#   -> TRADE: BUY AURIONPRO on 2022-11-17 at 172.50
#      -> Win Rate: 100.0%, Target: 198.37, Stop: 148.44
#   -> TRADE: BUY KDDL on 2022-11-17 at 1005.75
#      -> Win Rate: 100.0%, Target: 1156.61, Stop: 920.33
#   -> SKIPPED: UPL - Poor win rate: 0.0%
#   -> SKIPPED: SHAKTIPUMP - Poor win rate: 0.0%
#   -> TRADE: BUY ORIENTBELL on 2022-11-22 at 523.45
#      -> Win Rate: 100.0%, Target: 601.97, Stop: 495.05
#   -> TRADE: BUY BSHSL on 2022-11-24 at 143.05
#      -> Win Rate: 100.0%, Target: 191.67, Stop: 124.09
#   -> SKIPPED: ASHAPURMIN - Poor win rate: 0.0%
#   -> TRADE: BUY MADHAV on 2022-11-25 at 43.00
#      -> Win Rate: 100.0%, Target: 49.45, Stop: 37.96
#   -> TRADE: BUY ASHAPURMIN on 2022-11-30 at 88.65
#      -> Win Rate: 100.0%, Target: 101.95, Stop: 74.81
#   -> TRADE: BUY SHAKTIPUMP on 2022-11-30 at 73.17
#      -> Win Rate: 100.0%, Target: 84.14, Stop: 67.30
#   -> TRADE: BUY LAGNAM on 2022-12-02 at 60.70
#      -> Win Rate: 100.0%, Target: 69.81, Stop: 52.69
#   -> TRADE: BUY TDPOWERSYS on 2022-12-07 at 129.90
#      -> Win Rate: 100.0%, Target: 149.38, Stop: 113.61
#   -> TRADE: BUY SHALBY on 2022-12-09 at 153.95
#      -> Win Rate: 100.0%, Target: 177.04, Stop: 136.79
#   -> TRADE: BUY MAHICKRA on 2022-12-09 at 80.00
#      -> Win Rate: 100.0%, Target: 92.00, Stop: 72.42
#   -> SKIPPED: STEL - Poor win rate: 0.0%
#   -> SKIPPED: NCLIND - Poor win rate: 0.0%
#   -> TRADE: BUY ASHAPURMIN on 2022-12-22 at 81.50
#      -> Win Rate: 100.0%, Target: 93.72, Stop: 68.38
#   -> TRADE: BUY TVSSRICHAK on 2022-12-22 at 3160.15
#      -> Win Rate: 100.0%, Target: 3634.17, Stop: 2687.47
#   -> SKIPPED: NCLIND - Poor win rate: 0.0%
#   -> SKIPPED: ORIENTBELL - Poor win rate: 0.0%
#   -> TRADE: BUY LAMBODHARA on 2022-12-27 at 96.80
#      -> Win Rate: 100.0%, Target: 111.32, Stop: 77.07
#   -> TRADE: BUY TITAGARH on 2022-12-27 at 199.80
#      -> Win Rate: 100.0%, Target: 229.77, Stop: 177.67
#   -> SKIPPED: TAINWALCHM - Poor win rate: 0.0%
#   -> TRADE: BUY SREEL on 2022-12-29 at 209.00
#      -> Win Rate: 100.0%, Target: 240.35, Stop: 196.85
#   -> TRADE: BUY HIKAL on 2022-12-29 at 348.30
#      -> Win Rate: 100.0%, Target: 400.54, Stop: 302.67
#   -> TRADE: BUY MAHICKRA on 2023-01-04 at 81.00
#      -> Win Rate: 100.0%, Target: 98.23, Stop: 72.66
#   -> TRADE: BUY JSLL on 2023-01-19 at 155.00
#      -> Win Rate: 100.0%, Target: 178.25, Stop: 133.88
#   -> TRADE: BUY BAJAJFINSV on 2023-01-20 at 1360.00
#      -> Win Rate: 100.0%, Target: 1564.00, Stop: 1252.13
#   -> TRADE: BUY JINDALSAW on 2023-02-01 at 62.50
#      -> Win Rate: 100.0%, Target: 71.88, Stop: 54.23
#   -> TRADE: BUY ZENSARTECH on 2023-02-02 at 232.05
#      -> Win Rate: 100.0%, Target: 268.25, Stop: 200.76
#   -> TRADE: BUY TIRUMALCHM on 2023-02-02 at 176.50
#      -> Win Rate: 100.0%, Target: 202.97, Stop: 158.54
#   -> TRADE: BUY ERIS on 2023-02-07 at 629.15
#      -> Win Rate: 100.0%, Target: 723.52, Stop: 599.43
#   -> SKIPPED: ORIENTBELL - Poor win rate: 0.0%
#   -> TRADE: BUY SSWL on 2023-02-09 at 148.75
#      -> Win Rate: 100.0%, Target: 171.06, Stop: 135.86
#   -> TRADE: BUY LINC on 2023-02-09 at 122.51
#      -> Win Rate: 100.0%, Target: 140.89, Stop: 110.36
#   -> TRADE: BUY ORIENTBELL on 2023-02-09 at 510.00
#      -> Win Rate: 100.0%, Target: 586.50, Stop: 476.06
#   -> TRADE: BUY JINDALSAW on 2023-02-17 at 73.82
#      -> Win Rate: 100.0%, Target: 87.23, Stop: 63.62
#   -> TRADE: BUY TALBROAUTO on 2023-02-23 at 89.08
#      -> Win Rate: 100.0%, Target: 102.44, Stop: 79.45
#   -> TRADE: BUY PSPPROJECT on 2023-02-24 at 668.05
#      -> Win Rate: 100.0%, Target: 768.26, Stop: 644.55
#   -> SKIPPED: BAJAJHLDNG - Poor win rate: 0.0%
#   -> TRADE: BUY NCLIND on 2023-02-28 at 168.50
#      -> Win Rate: 100.0%, Target: 193.77, Stop: 162.48
#   -> TRADE: BUY CONFIPET on 2023-02-28 at 58.75
#      -> Win Rate: 100.0%, Target: 67.56, Stop: 51.24
#   -> TRADE: BUY RGL on 2023-02-28 at 87.50
#      -> Win Rate: 100.0%, Target: 100.62, Stop: 77.51
#   -> TRADE: BUY KCP on 2023-03-02 at 96.70
#      -> Win Rate: 100.0%, Target: 111.20, Stop: 88.88
#   -> TRADE: BUY ZYDUSWELL on 2023-03-02 at 1458.10
#      -> Win Rate: 100.0%, Target: 1676.81, Stop: 1369.10
#   -> TRADE: BUY KAKATCEM on 2023-03-03 at 190.60
#      -> Win Rate: 100.0%, Target: 219.19, Stop: 178.58
#   -> TRADE: BUY MAHICKRA on 2023-03-15 at 99.40
#      -> Win Rate: 100.0%, Target: 114.31, Stop: 93.58
#   -> TRADE: BUY PDMJEPAPER on 2023-03-15 at 39.65
#      -> Win Rate: 100.0%, Target: 45.60, Stop: 35.36
#   -> TRADE: BUY ALMONDZ on 2023-03-15 at 10.81
#      -> Win Rate: 100.0%, Target: 12.43, Stop: 9.94
#   -> SKIPPED: VINEETLAB - Poor win rate: 0.0%
#   -> TRADE: BUY TOKYOPLAST on 2023-03-16 at 90.20
#      -> Win Rate: 100.0%, Target: 103.73, Stop: 81.71
#   -> SKIPPED: GATEWAY - Poor win rate: 0.0%
#   -> TRADE: BUY GREAVESCOT on 2023-03-23 at 127.85
#      -> Win Rate: 100.0%, Target: 147.03, Stop: 117.02
#   -> TRADE: BUY JAICORPLTD on 2023-03-24 at 131.20
#      -> Win Rate: 100.0%, Target: 150.88, Stop: 116.10
#   -> SKIPPED: SUNTECK - Poor win rate: 0.0%
#   -> TRADE: BUY SDBL on 2023-03-28 at 55.56
#      -> Win Rate: 100.0%, Target: 63.89, Stop: 47.93
#   -> TRADE: BUY MAHSEAMLES on 2023-03-28 at 345.25
#      -> Win Rate: 100.0%, Target: 411.66, Stop: 316.69
#   -> TRADE: BUY MOTILALOFS on 2023-03-29 at 570.00
#      -> Win Rate: 100.0%, Target: 655.50, Stop: 523.77
#   -> TRADE: BUY AMEYA on 2023-03-29 at 35.00
#      -> Win Rate: 100.0%, Target: 41.76, Stop: 30.53
#   -> TRADE: BUY ROHLTD on 2023-03-31 at 277.90
#      -> Win Rate: 100.0%, Target: 319.58, Stop: 251.00
#   -> SKIPPED: KRISHANA - Poor win rate: 0.0%
#   -> TRADE: BUY SDBL on 2023-05-26 at 86.86
#      -> Win Rate: 100.0%, Target: 119.73, Stop: 74.24
#   -> TRADE: BUY GNA on 2023-05-26 at 383.40
#      -> Win Rate: 100.0%, Target: 440.91, Stop: 360.36
#   -> TRADE: BUY CENTRUM on 2023-05-31 at 18.10
#      -> Win Rate: 100.0%, Target: 20.82, Stop: 15.71
#   -> TRADE: BUY CSLFINANCE on 2023-06-01 at 204.80
#      -> Win Rate: 100.0%, Target: 323.69, Stop: 161.51
#   -> SKIPPED: PSPPROJECT - Poor win rate: 0.0%
#   -> SKIPPED: TMB - Poor win rate: 0.0%
#   -> TRADE: BUY MADHAV on 2023-06-07 at 42.60
#      -> Win Rate: 100.0%, Target: 48.99, Stop: 36.87
#   -> SKIPPED: NRAIL - Poor win rate: 0.0%
#   -> TRADE: BUY ASIANENE on 2023-06-07 at 111.00
#      -> Win Rate: 100.0%, Target: 142.97, Stop: 98.68
#   -> TRADE: BUY SOMATEX on 2023-06-08 at 29.90
#      -> Win Rate: 100.0%, Target: 34.38, Stop: 24.84
#   -> TRADE: BUY PRAKASHSTL on 2023-06-09 at 4.45
#      -> Win Rate: 100.0%, Target: 5.12, Stop: 4.18
#   -> TRADE: BUY TTL on 2023-06-09 at 7.84
#      -> Win Rate: 100.0%, Target: 9.02, Stop: 7.00
#   -> TRADE: BUY AVONMORE on 2023-06-15 at 6.84
#      -> Win Rate: 100.0%, Target: 7.87, Stop: 6.06
#   -> TRADE: BUY KRITINUT on 2023-06-15 at 53.40
#      -> Win Rate: 100.0%, Target: 66.92, Stop: 46.20
#   -> TRADE: BUY SOMATEX on 2023-06-15 at 24.40
#      -> Win Rate: 100.0%, Target: 28.06, Stop: 20.97
#   -> TRADE: BUY GREAVESCOT on 2023-06-16 at 139.05
#      -> Win Rate: 100.0%, Target: 159.91, Stop: 133.80
#   -> TRADE: BUY LOTUSEYE on 2023-06-20 at 80.00
#      -> Win Rate: 100.0%, Target: 92.00, Stop: 71.76
#   -> TRADE: BUY JSLL on 2023-06-21 at 251.25
#      -> Win Rate: 100.0%, Target: 325.54, Stop: 200.21
#   -> SKIPPED: NCLIND - Poor win rate: 0.0%
#   -> SKIPPED: KRISHANA - Poor win rate: 0.0%
#   -> SKIPPED: COSMOFIRST - Poor win rate: 0.0%
#   -> SKIPPED: HDFCLIFE - Poor win rate: 0.0%
#   -> SKIPPED: TIRUMALCHM - Poor win rate: 0.0%
#   -> TRADE: BUY MUKANDLTD on 2023-06-30 at 125.80
#      -> Win Rate: 100.0%, Target: 155.71, Stop: 109.57
#   -> TRADE: BUY MAHICKRA on 2023-07-05 at 85.00
#      -> Win Rate: 100.0%, Target: 97.75, Stop: 77.59
#   -> TRADE: BUY EUROBOND on 2023-07-18 at 119.00
#      -> Win Rate: 100.0%, Target: 161.69, Stop: 104.71
#   -> TRADE: BUY PAISALO on 2023-08-04 at 33.30
#      -> Win Rate: 100.0%, Target: 38.29, Stop: 30.98
#   -> TRADE: BUY NIBL on 2023-08-09 at 23.40
#      -> Win Rate: 100.0%, Target: 29.21, Stop: 21.96
#   -> TRADE: BUY ZYDUSWELL on 2023-08-11 at 1539.95
#      -> Win Rate: 100.0%, Target: 1770.94, Stop: 1442.16
#   -> TRADE: BUY NAVA on 2023-08-22 at 197.98
#      -> Win Rate: 100.0%, Target: 227.67, Stop: 182.28
#   -> TRADE: BUY GREAVESCOT on 2023-08-23 at 136.20
#      -> Win Rate: 100.0%, Target: 156.63, Stop: 121.54
#   -> TRADE: BUY KPIGREEN on 2023-08-23 at 194.67
#      -> Win Rate: 100.0%, Target: 223.87, Stop: 174.80
#   -> TRADE: BUY LINCOLN on 2023-08-24 at 468.95
#      -> Win Rate: 100.0%, Target: 539.29, Stop: 441.59
#   -> TRADE: BUY STEL on 2023-08-24 at 217.00
#      -> Win Rate: 100.0%, Target: 249.55, Stop: 198.82
#   -> TRADE: BUY NRBBEARING on 2023-08-25 at 249.00
#      -> Win Rate: 100.0%, Target: 295.49, Stop: 226.33
#   -> SKIPPED: SDBL - Poor win rate: 0.0%
#   -> TRADE: BUY NIBL on 2023-08-31 at 26.05
#      -> Win Rate: 100.0%, Target: 34.31, Stop: 24.81
#   -> TRADE: BUY PKTEA on 2023-08-31 at 303.50
#      -> Win Rate: 100.0%, Target: 349.02, Stop: 271.01
#   -> SKIPPED: INDOCO - Poor win rate: 0.0%
#   -> TRADE: BUY CHOICEIN on 2023-09-07 at 204.95
#      -> Win Rate: 100.0%, Target: 236.78, Stop: 193.82
#   -> TRADE: BUY REMUS on 2023-09-07 at 4450.00
#      -> Win Rate: 100.0%, Target: 5117.50, Stop: 4027.06
#   -> TRADE: BUY MONARCH on 2023-09-12 at 173.40
#      -> Win Rate: 100.0%, Target: 212.36, Stop: 155.42
#   -> TRADE: BUY SDBL on 2023-09-21 at 126.42
#      -> Win Rate: 100.0%, Target: 145.38, Stop: 112.66
#   -> TRADE: BUY MAHICKRA on 2023-09-22 at 82.70
#      -> Win Rate: 100.0%, Target: 95.10, Stop: 76.73
#   -> TRADE: BUY MAHSEAMLES on 2023-09-27 at 608.45
#      -> Win Rate: 100.0%, Target: 711.79, Stop: 551.69
#   -> TRADE: BUY AIROLAM on 2023-09-28 at 116.00
#      -> Win Rate: 100.0%, Target: 133.40, Stop: 106.77
#   -> TRADE: BUY MANGLMCEM on 2023-10-04 at 367.80
#      -> Win Rate: 100.0%, Target: 422.97, Stop: 350.25
#   -> TRADE: BUY JSL on 2023-11-02 at 452.95
#      -> Win Rate: 100.0%, Target: 528.71, Stop: 397.30
#   -> TRADE: BUY VENUSPIPES on 2023-11-07 at 1429.90
#      -> Win Rate: 100.0%, Target: 1644.39, Stop: 1234.93
#   -> TRADE: BUY STEL on 2023-11-08 at 245.00
#      -> Win Rate: 100.0%, Target: 281.75, Stop: 223.16
#   -> SKIPPED: ORIENTBELL - Poor win rate: 0.0%
#   -> TRADE: BUY JSL on 2023-11-23 at 504.45
#      -> Win Rate: 100.0%, Target: 580.12, Stop: 446.17
#   -> TRADE: BUY RACE on 2023-11-24 at 322.80
#      -> Win Rate: 100.0%, Target: 388.25, Stop: 294.80
#   -> TRADE: BUY HERCULES on 2023-11-28 at 358.90
#      -> Win Rate: 100.0%, Target: 412.73, Stop: 298.66
#   -> TRADE: BUY NRBBEARING on 2023-11-29 at 261.00
#      -> Win Rate: 100.0%, Target: 300.15, Stop: 234.42
#   -> TRADE: BUY REMUS on 2023-12-07 at 5499.00
#      -> Win Rate: 100.0%, Target: 7116.57, Stop: 4666.22
#   -> TRADE: BUY KRISHANA on 2023-12-08 at 235.95
#      -> Win Rate: 100.0%, Target: 271.34, Stop: 229.28
#   -> TRADE: BUY STARCEMENT on 2023-12-08 at 165.95
#      -> Win Rate: 100.0%, Target: 190.84, Stop: 157.18
#   -> TRADE: BUY SUNDARMFIN on 2023-12-08 at 3355.00
#      -> Win Rate: 100.0%, Target: 3858.25, Stop: 3199.16
#   -> TRADE: BUY KCP on 2023-12-13 at 143.60
#      -> Win Rate: 100.0%, Target: 165.14, Stop: 131.02
#   -> TRADE: BUY PAISALO on 2023-12-14 at 49.58
#      -> Win Rate: 100.0%, Target: 57.01, Stop: 41.28
#   -> SKIPPED: STEL - Poor win rate: 0.0%
#   -> TRADE: BUY STARTECK on 2023-12-21 at 244.00
#      -> Win Rate: 100.0%, Target: 330.13, Stop: 163.44
#   -> TRADE: BUY STEL on 2023-12-21 at 279.05
#      -> Win Rate: 100.0%, Target: 320.91, Stop: 246.75
#   -> TRADE: BUY FUSION on 2023-12-22 at 572.20
#      -> Win Rate: 100.0%, Target: 658.03, Stop: 522.04
#   -> TRADE: BUY PRAKASHSTL on 2023-12-22 at 8.75
#      -> Win Rate: 100.0%, Target: 16.52, Stop: 7.33
#   -> TRADE: BUY YASHO on 2023-12-28 at 1649.00
#      -> Win Rate: 100.0%, Target: 1896.35, Stop: 1539.28
#   -> TRADE: BUY NRBBEARING on 2024-01-03 at 353.90
#      -> Win Rate: 100.0%, Target: 455.39, Stop: 289.89
#   -> TRADE: BUY REMUS on 2024-01-24 at 6349.95
#      -> Win Rate: 100.0%, Target: 7302.44, Stop: 5703.78
#   -> TRADE: BUY MAHICKRA on 2024-01-25 at 121.20
#      -> Win Rate: 100.0%, Target: 139.38, Stop: 107.39
#   -> TRADE: BUY JSL on 2024-01-30 at 559.20
#      -> Win Rate: 100.0%, Target: 643.08, Stop: 512.72
#   -> TRADE: BUY MOXSH on 2024-02-07 at 138.85
#      -> Win Rate: 100.0%, Target: 162.63, Stop: 113.04
#   -> TRADE: BUY HCLTECH on 2024-02-09 at 1640.00
#      -> Win Rate: 100.0%, Target: 1886.00, Stop: 1535.53
#   -> TRADE: BUY SDBL on 2024-02-14 at 99.18
#      -> Win Rate: 100.0%, Target: 114.06, Stop: 81.37
#   -> TRADE: BUY DIAMINESQ on 2024-02-14 at 465.80
#      -> Win Rate: 100.0%, Target: 535.67, Stop: 392.16
#   -> SKIPPED: GNA - Poor win rate: 0.0%
#   -> TRADE: BUY STEL on 2024-02-21 at 320.00
#      -> Win Rate: 100.0%, Target: 368.00, Stop: 260.30
#   -> TRADE: BUY MAHSEAMLES on 2024-02-22 at 976.05
#      -> Win Rate: 100.0%, Target: 1122.46, Stop: 884.75
#   -> TRADE: BUY CHOICEIN on 2024-02-23 at 290.00
#      -> Win Rate: 100.0%, Target: 352.67, Stop: 276.13
#   -> SKIPPED: MDL - Poor win rate: 0.0%
#   -> TRADE: BUY JSL on 2024-03-06 at 687.40
#      -> Win Rate: 100.0%, Target: 790.51, Stop: 612.05
#   -> TRADE: BUY GANESHBE on 2024-03-06 at 195.30
#      -> Win Rate: 100.0%, Target: 224.60, Stop: 182.78
#   -> TRADE: BUY KPIGREEN on 2024-03-06 at 563.33
#      -> Win Rate: 100.0%, Target: 647.83, Stop: 518.07
#   -> TRADE: BUY UMA on 2024-03-07 at 29.35
#      -> Win Rate: 100.0%, Target: 34.11, Stop: 26.85
#   -> TRADE: BUY COOLCAPS on 2024-03-07 at 450.00
#      -> Win Rate: 100.0%, Target: 517.50, Stop: 421.23
#   -> TRADE: BUY ARROWGREEN on 2024-03-07 at 399.90
#      -> Win Rate: 100.0%, Target: 459.88, Stop: 337.58
#   -> TRADE: BUY PRAKASHSTL on 2024-03-14 at 7.25
#      -> Win Rate: 100.0%, Target: 8.75, Stop: 6.17
#   -> TRADE: BUY NUVOCO on 2024-03-15 at 303.35
#      -> Win Rate: 100.0%, Target: 348.85, Stop: 252.82
#   -> TRADE: BUY SARLAPOLY on 2024-03-15 at 53.65
#      -> Win Rate: 100.0%, Target: 61.70, Stop: 47.84
#   -> TRADE: BUY BHARATWIRE on 2024-03-20 at 277.05
#      -> Win Rate: 100.0%, Target: 318.61, Stop: 249.48
#   -> SKIPPED: ASHAPURMIN - Poor win rate: 0.0%
#   -> TRADE: BUY SATIN on 2024-03-21 at 202.35
#      -> Win Rate: 100.0%, Target: 236.32, Stop: 182.26
#   -> TRADE: BUY GOKULAGRO on 2024-03-21 at 109.35
#      -> Win Rate: 100.0%, Target: 125.75, Stop: 102.14
#   -> TRADE: BUY STARCEMENT on 2024-03-21 at 207.30
#      -> Win Rate: 100.0%, Target: 238.40, Stop: 179.81
#   -> TRADE: BUY NRBBEARING on 2024-03-21 at 269.10
#      -> Win Rate: 100.0%, Target: 309.47, Stop: 243.57
#   -> SKIPPED: MOXSH - Poor win rate: 0.0%
#   -> TRADE: BUY NCLIND on 2024-03-21 at 186.30
#      -> Win Rate: 100.0%, Target: 214.25, Stop: 167.14
#   -> TRADE: BUY STEL on 2024-05-16 at 330.00
#      -> Win Rate: 100.0%, Target: 426.97, Stop: 291.21
#   -> TRADE: BUY CANTABIL on 2024-05-30 at 218.55
#      -> Win Rate: 100.0%, Target: 256.17, Stop: 184.17
#   -> TRADE: BUY REMUS on 2024-05-31 at 1816.50
#      -> Win Rate: 100.0%, Target: 2537.14, Stop: 1362.31
#   -> TRADE: BUY DBCORP on 2024-06-05 at 280.50
#      -> Win Rate: 100.0%, Target: 347.31, Stop: 245.77
#   -> TRADE: BUY MANAPPURAM on 2024-06-05 at 164.00
#      -> Win Rate: 100.0%, Target: 195.76, Stop: 147.65
#   -> TRADE: BUY NAVA on 2024-06-06 at 258.50
#      -> Win Rate: 100.0%, Target: 297.27, Stop: 225.72
#   -> TRADE: BUY SBCL on 2024-06-06 at 508.30
#      -> Win Rate: 100.0%, Target: 604.28, Stop: 459.97
#   -> TRADE: BUY SNOWMAN on 2024-06-06 at 67.70
#      -> Win Rate: 100.0%, Target: 82.15, Stop: 60.55
#   -> TRADE: BUY SEAMECLTD on 2024-06-06 at 1038.00
#      -> Win Rate: 100.0%, Target: 1423.71, Stop: 947.26
#   -> TRADE: BUY INDOCO on 2024-06-06 at 311.20
#      -> Win Rate: 100.0%, Target: 361.83, Stop: 297.16
#   -> TRADE: BUY JINDALSAW on 2024-06-07 at 263.50
#      -> Win Rate: 100.0%, Target: 303.02, Stop: 223.98
#   -> TRADE: BUY LINCOLN on 2024-06-07 at 594.80
#      -> Win Rate: 100.0%, Target: 695.81, Stop: 548.33
#   -> TRADE: BUY INFOBEAN on 2024-06-07 at 429.10
#      -> Win Rate: 100.0%, Target: 498.92, Stop: 373.97
#   -> TRADE: BUY SHEKHAWATI on 2024-06-12 at 4.12
#      -> Win Rate: 100.0%, Target: 5.21, Stop: 3.86
#   -> TRADE: BUY BAJFINANCE on 2024-06-14 at 729.60
#      -> Win Rate: 100.0%, Target: 839.05, Stop: 663.97
#   -> SKIPPED: SDBL - Poor win rate: 0.0%
#   -> TRADE: BUY GREENPLY on 2024-06-21 at 306.40
#      -> Win Rate: 100.0%, Target: 352.36, Stop: 267.63
#   -> TRADE: BUY VEEDOL on 2024-06-27 at 2186.15
#      -> Win Rate: 100.0%, Target: 2641.62, Stop: 1915.44
#   -> SKIPPED: TTL - Poor win rate: 0.0%
#   -> TRADE: BUY MDL on 2024-07-03 at 106.00
#      -> Win Rate: 100.0%, Target: 121.90, Stop: 92.25
#   -> SKIPPED: BAJAJFINSV - Poor win rate: 0.0%
#   -> TRADE: BUY MANINFRA on 2024-08-13 at 191.99
#      -> Win Rate: 100.0%, Target: 220.79, Stop: 178.07
#   -> SKIPPED: USHAMART - Poor win rate: 0.0%
#   -> TRADE: BUY REMUS on 2024-08-21 at 2645.00
#      -> Win Rate: 100.0%, Target: 3241.04, Stop: 2284.24
#   -> TRADE: BUY USHAMART on 2024-08-22 at 332.20
#      -> Win Rate: 100.0%, Target: 382.03, Stop: 308.77
#   -> TRADE: BUY STEL on 2024-08-23 at 488.00
#      -> Win Rate: 100.0%, Target: 561.20, Stop: 440.36
#   -> TRADE: BUY LAXMICOT on 2024-08-28 at 35.55
#      -> Win Rate: 100.0%, Target: 40.88, Stop: 26.42
#   -> TRADE: BUY KPIGREEN on 2024-08-28 at 610.67
#      -> Win Rate: 100.0%, Target: 702.27, Stop: 558.08
#   -> TRADE: BUY COOLCAPS on 2024-08-29 at 395.00
#      -> Win Rate: 100.0%, Target: 663.76, Stop: 285.13
#   -> TRADE: BUY TOKYOPLAST on 2024-08-29 at 152.03
#      -> Win Rate: 100.0%, Target: 174.83, Stop: 122.45
#   -> TRADE: BUY DWARKESH on 2024-09-06 at 74.37
#      -> Win Rate: 100.0%, Target: 85.53, Stop: 69.43
#   -> TRADE: BUY STEL on 2024-09-19 at 542.05
#      -> Win Rate: 100.0%, Target: 623.36, Stop: 505.35
#   -> TRADE: BUY LTFOODS on 2024-10-31 at 378.95
#      -> Win Rate: 100.0%, Target: 435.79, Stop: 340.58
#   -> TRADE: BUY DIAMINESQ on 2024-11-07 at 527.20
#      -> Win Rate: 100.0%, Target: 606.28, Stop: 483.35
#   -> TRADE: BUY ORIENTBELL on 2024-11-14 at 315.00
#      -> Win Rate: 100.0%, Target: 362.25, Stop: 299.72
#   -> TRADE: BUY PKTEA on 2024-11-14 at 543.65
#      -> Win Rate: 100.0%, Target: 698.07, Stop: 479.67
#   -> SKIPPED: ALKYLAMINE - Poor win rate: 0.0%
#   -> TRADE: BUY INDOCO on 2024-11-14 at 311.00
#      -> Win Rate: 100.0%, Target: 357.65, Stop: 278.69
#   -> SKIPPED: NCLIND - Poor win rate: 0.0%
#   -> TRADE: BUY GREENPLY on 2024-11-21 at 325.00
#      -> Win Rate: 100.0%, Target: 373.75, Stop: 296.84
#   -> TRADE: BUY KECL on 2024-11-22 at 171.30
#      -> Win Rate: 100.0%, Target: 197.00, Stop: 156.45
#   -> SKIPPED: AVONMORE - Poor win rate: 0.0%
#   -> TRADE: BUY YASHOPTICS on 2024-11-29 at 83.00
#      -> Win Rate: 100.0%, Target: 95.45, Stop: 75.04
#   -> SKIPPED: TOKYOPLAST - Poor win rate: 0.0%
#   -> TRADE: BUY SNOWMAN on 2024-12-03 at 76.47
#      -> Win Rate: 100.0%, Target: 87.94, Stop: 68.43
#   -> TRADE: BUY AVONMORE on 2024-12-05 at 17.71
#      -> Win Rate: 100.0%, Target: 24.63, Stop: 13.49
#   -> TRADE: BUY UNITEDPOLY on 2024-12-05 at 13.75
#      -> Win Rate: 100.0%, Target: 15.98, Stop: 13.01
#   -> TRADE: BUY GNA on 2024-12-06 at 428.00
#      -> Win Rate: 100.0%, Target: 492.20, Stop: 396.25
#   -> TRADE: BUY JSL on 2024-12-10 at 746.80
#      -> Win Rate: 100.0%, Target: 858.82, Stop: 665.94
#   -> TRADE: BUY SILVERTUC on 2024-12-12 at 688.85
#      -> Win Rate: 100.0%, Target: 792.18, Stop: 660.51
#   -> TRADE: BUY PKTEA on 2024-12-19 at 765.05
#      -> Win Rate: 100.0%, Target: 879.81, Stop: 667.15
#   -> TRADE: BUY TARMAT on 2024-12-19 at 82.00
#      -> Win Rate: 100.0%, Target: 94.30, Stop: 76.41
#   -> TRADE: BUY BABAFP on 2024-12-19 at 55.10
#      -> Win Rate: 100.0%, Target: 63.36, Stop: 47.71
#   -> SKIPPED: YASHOPTICS - Poor win rate: 0.0%
#   -> TRADE: BUY ASHAPURMIN on 2025-01-01 at 389.50
#      -> Win Rate: 100.0%, Target: 447.92, Stop: 342.16
#   -> TRADE: BUY ANUP on 2025-01-02 at 3471.10
#      -> Win Rate: 100.0%, Target: 3991.77, Stop: 2861.88
#   -> TRADE: BUY REXPIPES on 2025-01-10 at 68.00
#      -> Win Rate: 100.0%, Target: 78.20, Stop: 58.81
#   -> TRADE: BUY RILINFRA on 2025-01-14 at 34.95
#      -> Win Rate: 100.0%, Target: 42.09, Stop: 27.57
#   -> TRADE: BUY SKP on 2025-01-17 at 251.00
#      -> Win Rate: 100.0%, Target: 288.65, Stop: 232.59
#   -> TRADE: BUY MARCO on 2025-01-22 at 57.55
#      -> Win Rate: 100.0%, Target: 73.81, Stop: 43.62
#   -> SKIPPED: YASHOPTICS - Poor win rate: 0.0%
#   -> TRADE: BUY TARACHAND on 2025-02-04 at 51.00
#      -> Win Rate: 100.0%, Target: 58.65, Stop: 43.71
#   -> TRADE: BUY DBCORP on 2025-02-13 at 200.00
#      -> Win Rate: 100.0%, Target: 259.96, Stop: 176.09
#   -> SKIPPED: AVSL - Poor win rate: 0.0%
#   -> TRADE: BUY LINC on 2025-02-14 at 120.20
#      -> Win Rate: 100.0%, Target: 138.23, Stop: 111.05
#   -> SKIPPED: RPTECH - Poor win rate: 0.0%
#   -> TRADE: BUY JINDALSTEL on 2025-02-19 at 840.00
#      -> Win Rate: 100.0%, Target: 966.00, Stop: 792.11
#   -> TRADE: BUY SARLAPOLY on 2025-02-19 at 71.89
#      -> Win Rate: 100.0%, Target: 82.67, Stop: 61.14
#   -> TRADE: BUY MAHSEAMLES on 2025-02-19 at 596.10
#      -> Win Rate: 100.0%, Target: 708.89, Stop: 534.45
#   -> TRADE: BUY NAHARSPING on 2025-02-20 at 212.50
#      -> Win Rate: 100.0%, Target: 244.37, Stop: 167.86
#   -> TRADE: BUY APS on 2025-02-20 at 415.95
#      -> Win Rate: 100.0%, Target: 478.34, Stop: 372.98
#   -> TRADE: BUY UGARSUGAR on 2025-02-20 at 47.75
#      -> Win Rate: 100.0%, Target: 54.91, Stop: 41.01
#   -> TRADE: BUY DIAMINESQ on 2025-02-20 at 356.75
#      -> Win Rate: 100.0%, Target: 410.26, Stop: 303.79
#   -> TRADE: BUY DEEPAKNTR on 2025-02-20 at 1911.45
#      -> Win Rate: 100.0%, Target: 2198.17, Stop: 1781.33
#   -> TRADE: BUY NCLIND on 2025-02-21 at 191.90
#      -> Win Rate: 100.0%, Target: 220.68, Stop: 177.43
#   -> TRADE: BUY KRISHANA on 2025-02-21 at 189.99
#      -> Win Rate: 100.0%, Target: 242.05, Stop: 167.55
#   -> SKIPPED: GLOBAL - Poor win rate: 0.0%
#   -> TRADE: BUY BLISSGVS on 2025-02-21 at 136.00
#      -> Win Rate: 100.0%, Target: 181.31, Stop: 115.17
#   -> TRADE: BUY CSLFINANCE on 2025-02-21 at 266.05
#      -> Win Rate: 100.0%, Target: 305.96, Stop: 236.09
#   -> TRADE: BUY CONTROLPR on 2025-02-27 at 592.00
#      -> Win Rate: 100.0%, Target: 680.80, Stop: 531.04
#   -> SKIPPED: SGIL - Poor win rate: 0.0%
#   -> SKIPPED: STEL - Poor win rate: 0.0%
#   -> TRADE: BUY SOLARA on 2025-03-13 at 490.05
#      -> Win Rate: 100.0%, Target: 563.56, Stop: 421.22
#   -> SKIPPED: YASHOPTICS - Poor win rate: 0.0%
#   -> TRADE: BUY SUNTECK on 2025-03-18 at 364.70
#      -> Win Rate: 100.0%, Target: 419.41, Stop: 311.82
#   -> TRADE: BUY OMFURN on 2025-03-18 at 84.40
#      -> Win Rate: 100.0%, Target: 104.23, Stop: 73.90
#   -> TRADE: BUY RPTECH on 2025-03-18 at 268.35
#      -> Win Rate: 100.0%, Target: 308.60, Stop: 235.23
#   -> SKIPPED: POONAWALLA - Poor win rate: 0.0%
#   -> TRADE: BUY RILINFRA on 2025-03-19 at 31.65
#      -> Win Rate: 100.0%, Target: 36.40, Stop: 27.27
#   -> TRADE: BUY AVONMORE on 2025-03-20 at 18.39
#      -> Win Rate: 100.0%, Target: 23.60, Stop: 15.67
#   -> TRADE: BUY PDMJEPAPER on 2025-03-20 at 103.78
#      -> Win Rate: 100.0%, Target: 119.35, Stop: 95.13
#   -> SKIPPED: TIMETECHNO - Poor win rate: 0.0%
#   -> TRADE: BUY GODREJAGRO on 2025-03-25 at 797.10
#      -> Win Rate: 100.0%, Target: 916.66, Stop: 709.08
#   -> TRADE: BUY TARACHAND on 2025-03-26 at 63.36
#      -> Win Rate: 100.0%, Target: 72.86, Stop: 56.29
#   -> TRADE: BUY PENIND on 2025-03-26 at 182.35
#      -> Win Rate: 100.0%, Target: 209.70, Stop: 159.37
#   -> TRADE: BUY APS on 2025-03-27 at 370.00
#      -> Win Rate: 100.0%, Target: 425.50, Stop: 303.98
#   -> SKIPPED: TREL - Poor win rate: 0.0%
#   -> TRADE: BUY DBCORP on 2025-05-14 at 230.09
#      -> Win Rate: 100.0%, Target: 264.60, Stop: 197.89
#   -> TRADE: BUY KPEL on 2025-05-20 at 491.40
#      -> Win Rate: 100.0%, Target: 565.11, Stop: 418.61
#   -> TRADE: BUY LTFOODS on 2025-05-21 at 377.00
#      -> Win Rate: 100.0%, Target: 433.55, Stop: 334.65
#   -> TRADE: BUY WESTLIFE on 2025-05-22 at 691.00
#      -> Win Rate: 100.0%, Target: 794.65, Stop: 654.09
#   -> TRADE: BUY TFCILTD on 2025-05-28 at 220.80
#      -> Win Rate: 100.0%, Target: 253.92, Stop: 203.89
#   -> TRADE: BUY GLOBAL on 2025-05-29 at 62.38
#      -> Win Rate: 100.0%, Target: 71.74, Stop: 56.08
#   -> TRADE: BUY AURIONPRO on 2025-05-29 at 1361.80
#      -> Win Rate: 100.0%, Target: 1610.86, Stop: 1255.45
#   -> SKIPPED: SILVERTUC - Poor win rate: 0.0%
#   -> SKIPPED: ORIENTBELL - Poor win rate: 0.0%
#   -> TRADE: BUY SDBL on 2025-06-04 at 142.78
#      -> Win Rate: 100.0%, Target: 164.20, Stop: 127.38
#   -> TRADE: BUY DBCORP on 2025-06-05 at 266.35
#      -> Win Rate: 100.0%, Target: 306.30, Stop: 246.66
#   -> TRADE: BUY AMBIKCO on 2025-06-05 at 1635.40
#      -> Win Rate: 100.0%, Target: 1880.71, Stop: 1531.67
#   -> TRADE: BUY ORIENTBELL on 2025-06-06 at 252.90
#      -> Win Rate: 100.0%, Target: 322.64, Stop: 209.34
#   -> TRADE: BUY WSI on 2025-06-11 at 77.28
#      -> Win Rate: 100.0%, Target: 96.89, Stop: 72.36
#   -> TRADE: BUY INTLCONV on 2025-06-12 at 84.59
#      -> Win Rate: 100.0%, Target: 97.28, Stop: 79.91
#   -> TRADE: BUY DHRUV on 2025-06-13 at 68.50
#      -> Win Rate: 100.0%, Target: 78.77, Stop: 61.77
#   -> TRADE: BUY LTFOODS on 2025-06-18 at 441.90
#      -> Win Rate: 100.0%, Target: 508.18, Stop: 405.37
#   -> TRADE: BUY MANINFRA on 2025-06-24 at 162.50
#      -> Win Rate: 100.0%, Target: 186.87, Stop: 147.19
#   -> TRADE: BUY ALMONDZ on 2025-07-01 at 25.65
#      -> Win Rate: 100.0%, Target: 29.50, Stop: 20.72
#   -> TRADE: BUY SGLTL on 2025-07-01 at 172.00
#      -> Win Rate: 100.0%, Target: 197.80, Stop: 159.48
# BACKTEST SIMULATION COMPLETE
# Total execution time: 54.02 seconds.
#
# --- Technical Indicators Summary ---
# Average ATR: 22.954
# Average Beta: 0.86
# Average Volatility: 0.448
# Average ADV: 22.6 Crores
#
# Per-Stock Performance
#             num_trades win_rate_pct avg_return_pct profit_factor avg_drawdown_pct trade_sharpe
# Symbol
# STEL                 7       71.43%         10.91%         22.46           -7.67%         0.90
# MAHSEAMLES           6       83.33%          8.07%          3.81           -8.07%         0.56
# MAHICKRA             6       66.67%          6.75%          5.10           -5.18%         0.51
# DBCORP               6       83.33%         11.20%          5.23           -7.83%         0.74
# SDBL                 6      100.00%         17.07%           inf           -8.17%         1.90
# REMUS                5       80.00%         12.90%          7.39           -7.32%         0.73
# JSL                  5       60.00%          9.07%          6.54           -8.27%         0.75
# KPIGREEN             4       25.00%         -1.85%          0.70          -10.21%        -0.15
# ORIENTBELL           4       75.00%          6.68%         15.05           -5.94%         0.53
# NRBBEARING           4       75.00%         10.59%         37.55           -4.75%         1.26
# NCLIND               4       75.00%          7.62%          6.92           -6.26%         0.70
# LTFOODS              3       66.67%          7.25%          3.15           -8.08%         0.48
# JINDALSAW            3      100.00%         14.26%           inf           -5.32%         2.63
# GNA                  3       33.33%          3.20%          2.47           -5.65%         0.28
# GREAVESCOT           3       66.67%          5.13%          6.71           -6.47%         0.53
# DIAMINESQ            3       66.67%          6.06%         20.37           -8.48%         0.56
# ASHAPURMIN           3       66.67%         10.75%          4.94           -7.48%         0.64
# AVONMORE             3       66.67%          6.84%          5.22          -10.81%         0.63
# VAIBHAVGBL           3       33.33%          4.05%          1.75           -6.55%         0.19
# PKTEA                3       33.33%          3.59%          1.53          -11.05%         0.15
# PRAKASHSTL           3       66.67%         19.51%           inf          -12.65%         1.05
# ZYDUSWELL            3       66.67%          0.98%          2.09           -7.44%         0.30
# STARCEMENT           3      100.00%          6.18%           inf           -7.33%         6.05
# TOKYOPLAST           3       66.67%          2.21%          1.34          -11.58%         0.10
